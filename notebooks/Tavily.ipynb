# %%
from tavily import TavilyClient

tavily_client = TavilyClient(api_key="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")
response = tavily_client.search("Who is Leo Messi?")

print(response)
# Out:
# {'query': 'Who is Leo Messi?', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.biography.com/athletes/lionel-messi', 'title': 'Lionel Messi: Biography, Soccer Player, Inter Miami CF, Athlete', 'content': 'Lionel Messi, a forward for Inter Miami CF, is one of the world’s greatest soccer players and helped the Argentina national team win its third FIFA World Cup in 2022. Lionel Messi is an Argentinian soccer player who has played for FC Barcelona, Paris Saint-Germain, and currently, the MLS club Inter Miami CF as well as the Argentina national team. Image 13: lionel messi kisses a gold trophy after his team won the 2022 fifa world cup, he wears an argentina national team jersey and holds the trophy in his hands Image 15: lionel messi, his wife, and three youth sons walk on a soccer field, all are wearing argentina national team jerseys and messi is holding up the fifa world cup trophy, behind them is a crowd in the stands', 'score': 0.9853843
# ...

# %%
print(response.keys())
# Out:
# dict_keys(['query', 'follow_up_questions', 'answer', 'images', 'results', 'response_time', 'request_id'])

# %%
results = response['results']
print(len(results))
# Out:
# 5

# %%
result = results[0]
print(result.keys())
# Out:
# dict_keys(['url', 'title', 'content', 'score', 'raw_content'])

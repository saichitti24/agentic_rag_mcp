# %%
from sentence_transformers import SentenceTransformer, util
# Out:
# WARNING:tensorflow:From C:\Users\amrutha sai\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load a pre-trained Sentence Transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')
print(model)
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False, 'architecture': 'BertModel'})
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
query = "What is my favorite all time movie?"

# %%
documents = [
    "Mahanati is one of the best movies in Indian cinema which truly depicts the ups and downs of Savithri amma's life which we all could connect to because we are also going through same emotions.",
    "I also like SagaraSangamam by Vishwanath, which truly depicts of the story of a loser. Same as in Mahanti, this too depicts the ups-downs of life. But mahanati tops for me as favourite movie.",
    "I think, Vaaranam Aayiram deserves the place here in third position. Again, its also slice of coming-age movie depicting life."
]

# %%
# Encode query and documents
query_embedding = model.encode(query)
doc_embeddings = model.encode(documents)

# %%
print(type(query_embedding))
print(query_embedding.shape)
print(doc_embeddings.shape)
# Out:
# <class 'numpy.ndarray'>
# (384,)
# (3, 384)

# %%
# Find the most similar document to the query
results = util.semantic_search(query_embedding, doc_embeddings, top_k=1)
print(results)
# Out:
# [[{'corpus_id': 1, 'score': 0.4398377537727356}]]

# %%
most_similar_doc = documents[results[0][0]['corpus_id']]
print(most_similar_doc)
# Out:
# I also like SagaraSangamam by Vishwanath, which truly depicts of the story of a loser. Same as in Mahanti, this too depicts the ups-downs of life. But mahanati tops for me as favourite movie.
